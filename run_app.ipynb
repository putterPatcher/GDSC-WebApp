# %%
# !pip install solara joblib

# %%
# !solara run main.py
# Out:
# Solara server is starting at http://localhost:8765
# Gtk-Message: 07:41:17.862: Not loading module "atk-bridge": The functionality is provided by GTK natively. Please try to not load it.
